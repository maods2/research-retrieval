# %%
from plotter import plot_metric_comparison_from_json
RESULTS_FILE = "../results/ALL_SEB_compiled_results_20260121_155212.json"
#RESULTS_FILE = "../results/ATT_METRIC_compiled_results_20260121_204852.json"

plot_metric_comparison_from_json(
    RESULTS_FILE,
    dataset_name="bracs",
    metric_key="map_compiled",
    title="Model Comparison on BRACS",
    save_as="bracs_map_comparison.pdf"
)
# Out:
# Models: dict_keys(['dino_v1_b16', 'virchow', 'phikon', 'dino_v2_b', 'uni', 'uni2h', 'virchow_v2', 'phikon_v2'])
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.5923076923076923, '3': 0.6416666666666666, '6': 0.6330470085470086, '9': 0.6208413897610326, '12': 0.6050159190957352, '15': 0.6011535778271047}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.43846153846153846, '3': 0.5512820512820513, '6': 0.5540320512820514, '9': 0.5355991627420199, '12': 0.5283570664744907, '15': 0.5227242145551273}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.5615384615384615, '3': 0.6358974358974359, '6': 0.6293012820512821, '9': 0.6221313230420372, '12': 0.6169527660190539, '15': 0.6080861178401795}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.4153846153846154, '3': 0.514102564102564, '6': 0.5173696581196582, '9': 0.5089109432234433, '12': 0.4984712349439081, '15': 0.4933063963859339}
# ...

# %%
plot_metric_comparison_from_json(
    RESULTS_FILE,
    dataset_name="glomerulo",
    metric_key="map_compiled",
    title="Model Comparison on glomerulo",
    save_as="glomerulo_map_comparison.pdf"
)
# Out:
# Models: dict_keys(['dino_v1_b16', 'virchow', 'phikon', 'dino_v2_b', 'uni', 'uni2h', 'virchow_v2', 'phikon_v2'])
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.7572559366754618, '3': 0.8135444151275287, '6': 0.8069437115215479, '9': 0.794787945961146, '12': 0.7849050797512301, '15': 0.7767074737173654}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.716358839050132, '3': 0.7730870712401056, '6': 0.7590431691586044, '9': 0.7387690036436738, '12': 0.7248906820299233, '15': 0.7139292729957504}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.787598944591029, '3': 0.8346525945470537, '6': 0.8294807241278217, '9': 0.816615032996488, '12': 0.8096061305631054, '15': 0.8025248777185046}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.6952506596306068, '3': 0.7527484608619173, '6': 0.7455148783347992, '9': 0.7340280918875907, '12': 0.7222193331594816, '15': 0.7160684086251293}
# ...

# %%
plot_metric_comparison_from_json(
    RESULTS_FILE,
    dataset_name="ubc-ovarian-cancer",
    metric_key="map_compiled",
    title="Model Comparison on ubc-ovarian-cancer",
    save_as="ubc-ovarian-cancer_map_comparison.pdf"
)
# Out:
# Models: dict_keys(['dino_v1_b16', 'virchow', 'phikon', 'dino_v2_b', 'uni', 'uni2h', 'virchow_v2', 'phikon_v2'])
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.7, '3': 0.7558333333333332, '6': 0.7316527777777777, '9': 0.7273383219954649, '12': 0.726188051237483, '15': 0.7205653082321163}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.7, '3': 0.7483333333333333, '6': 0.7302305555555556, '9': 0.7225260487528344, '12': 0.7082460433806212, '15': 0.6994867948103899}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.86, '3': 0.8825, '6': 0.8667305555555557, '9': 0.8452797052154196, '12': 0.8309126023687712, '15': 0.8238741809903815}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.61, '3': 0.6508333333333333, '6': 0.649375, '9': 0.643377380952381, '12': 0.6215045378933636, '15': 0.6165042006256438}
# info: dict_keys(['map_compiled', 'map_details'])
# ...

# %%
plot_metric_comparison_from_json(
    RESULTS_FILE,
    dataset_name="lung-colon",
    metric_key="map_compiled",
    title="Model Comparison on lung-colon",
    save_as="lung-colon_map_comparison.pdf"
)
# Out:
# Models: dict_keys(['dino_v1_b16', 'virchow', 'phikon', 'dino_v2_b', 'uni', 'uni2h', 'virchow_v2', 'phikon_v2'])
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 1.0, '3': 0.9983333333333334, '6': 0.9977083333333334, '9': 0.9972916666666666, '12': 0.9970975378787879, '15': 0.9969439533680604}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 1.0, '3': 0.9983333333333333, '6': 0.9977222222222223, '9': 0.9966631944444445, '12': 0.992682621671258, '15': 0.9897611372121237}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 1.0, '3': 1.0, '6': 1.0, '9': 1.0, '12': 1.0, '15': 1.0}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 1.0, '3': 0.9983333333333333, '6': 0.9959888888888889, '9': 0.9936428571428572, '12': 0.9917808457956185, '15': 0.9907636344458688}
# info: dict_keys(['map_compiled', 'map_details'])
# ...

# %%
plot_metric_comparison_from_json(
    RESULTS_FILE,
    dataset_name="crc-val-he-7k",
    metric_key="map_compiled",
    title="Model Comparison on crc-val-he-7k",
    save_as="crc-val-he-7k_map_comparison.pdf"
)
# Out:
# Models: dict_keys(['dino_v1_b16', 'virchow', 'phikon', 'dino_v2_b', 'uni', 'uni2h', 'virchow_v2', 'phikon_v2'])
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.9943820224719101, '3': 0.99625468164794, '6': 0.9956554307116104, '9': 0.9950501525516573, '12': 0.9948374007107409, '15': 0.994840845573189}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 1.0, '3': 0.999063670411985, '6': 0.9983005617977527, '9': 0.9974651424240109, '12': 0.9970595549672838, '15': 0.9969041437679541}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 1.0, '3': 1.0, '6': 1.0, '9': 1.0, '12': 1.0, '15': 1.0}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.9831460674157303, '3': 0.9897003745318351, '6': 0.9922612359550562, '9': 0.9916775347779562, '12': 0.99147699267592, '15': 0.9911188115696389}
# info: dict_keys(['map_compiled', 'map_details'])
# ...

# %%
plot_metric_comparison_from_json(
    RESULTS_FILE,
    dataset_name="skin-cancer",
    metric_key="map_compiled",
    title="Model Comparison on skin-cancer",
    save_as="skin-cancer_map_comparison.pdf"
)
# Out:
# Models: dict_keys(['dino_v1_b16', 'virchow', 'phikon', 'dino_v2_b', 'uni', 'uni2h', 'virchow_v2', 'phikon_v2'])
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.5797101449275363, '3': 0.6400966183574879, '6': 0.63432769726248, '9': 0.6380855023168687, '12': 0.6301929370138636, '15': 0.628234228795075}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.38405797101449274, '3': 0.4855072463768116, '6': 0.5093900966183574, '9': 0.5018635697032436, '12': 0.49440625349777034, '15': 0.48721078232963094}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.5217391304347826, '3': 0.5730676328502416, '6': 0.5740539452495974, '9': 0.5587706525847053, '12': 0.5515463604915578, '15': 0.5455710941508296}
# info: dict_keys(['map_compiled', 'map_details'])
# data: {'1': 0.5652173913043478, '3': 0.6201690821256038, '6': 0.6225583735909823, '9': 0.6171242893292582, '12': 0.6113161665366164, '15': 0.6072319628803982}
# ...
